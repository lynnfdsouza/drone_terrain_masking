# %% [markdown]
# <a href="https://colab.research.google.com/github/lynnfdsouza/drone_terrain_masking/blob/main/Real_Sensor_API_Integration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

class KalmanFilter1D:
    """Simple 1D Kalman Filter for position/velocity estimation."""
    def __init__(self, x0=0, v0=0, accel_var=0.1, meas_var=1.0):
        self.x = x0
        self.v = v0
        self.P = np.eye(2)
        self.F = np.eye(2)
        self.Q = np.array([[0.25, 0.5],[0.5, 1.0]]) * accel_var
        self.H = np.array([[1, 0]])  # Position measurement only
        self.R = np.array([[meas_var]])

    def predict(self, dt, accel=0):
        # State transition
        self.F = np.array([[1, dt], [0, 1]])
        B = np.array([[0.5*dt**2], [dt]])
        u = np.array([[accel]])
        state = np.array([[self.x], [self.v]])
        state = self.F @ state + B @ u
        self.x, self.v = state.flatten()
        # Covariance update
        self.P = self.F @ self.P @ self.F.T + self.Q

    def update(self, z):
        y = z - (self.H @ np.array([[self.x], [self.v]]))
        S = self.H @ self.P @ self.H.T + self.R
        K = self.P @ self.H.T @ np.linalg.inv(S)
        state = np.array([[self.x], [self.v]]) + K @ y
        self.x, self.v = state.flatten()
        I = np.eye(2)
        self.P = (I - K @ self.H) @ self.P

class ObstacleAvoidance:
    """Obstacle avoidance using simulated LIDAR/range data."""
    def __init__(self, min_dist=5.0):
        self.min_dist = min_dist

    def check_obstacles(self, lidar_ranges):
        # lidar_ranges: list of (angle, distance)
        for angle, dist in lidar_ranges:
            if dist < self.min_dist:
                print(f"Obstacle detected at {angle}°: {dist:.2f}m")
                return True, angle
        return False, None

    def avoidance_direction(self, obstacle_angle):
        # Simple logic: turn away from detected obstacle
        if obstacle_angle < 0:
            return "right"
        else:
            return "left"

class RealSensorAPI:
    """Stub class: Replace with actual sensor API calls."""
    def get_acceleration(self):
        # Replace with real sensor read
        return np.random.randn(3) * 0.02

    def get_gyroscope(self):
        return np.random.randn(3) * 0.01

    def get_position(self):
        # From external source, e.g., visual odometry or quantum position sensor
        return np.random.randn(3) * 0.5

    def get_lidar_ranges(self):
        # Simulated 8-direction LIDAR (angle in degrees, distance in meters)
        return [(a, 10 + np.random.uniform(-2, 2)) for a in range(-90, 91, 30)]

def terrain_elevation(x, y):
    # Example: rolling hills
    return 15.0 * np.sin(0.03*x) * np.cos(0.04*y) + 30

def main():
    # Initialize filters for each axis (x, y, z)
    kf_x = KalmanFilter1D()
    kf_y = KalmanFilter1D()
    kf_z = KalmanFilter1D(x0=50.0)
    obstacle_avoid = ObstacleAvoidance()
    sensors = RealSensorAPI()

    dt = 0.1  # 10 Hz update rate
    for t in np.arange(0, 30, dt):
        accel = sensors.get_acceleration()
        pos_meas = sensors.get_position()
        lidar = sensors.get_lidar_ranges()

        # Predict step (assume measured acceleration)
        kf_x.predict(dt, accel=accel[0])
        kf_y.predict(dt, accel=accel[1])
        kf_z.predict(dt, accel=accel[2])

        # Update step (use external position measurement)
        kf_x.update(pos_meas[0])
        kf_y.update(pos_meas[1])
        kf_z.update(pos_meas[2])

        # Terrain masking
        terrain = terrain_elevation(kf_x.x, kf_y.x)
        altitude_buffer = 10
        if kf_z.x < terrain + altitude_buffer:
            kf_z.x = terrain + altitude_buffer
            print(f"Terrain masking: Adjusted altitude to {kf_z.x:.1f}m")

        # Obstacle avoidance
        obstacle, angle = obstacle_avoid.check_obstacles(lidar)
        if obstacle:
            turn = obstacle_avoid.avoidance_direction(angle)
            print(f"Obstacle at {angle}°, turning {turn}")

        # (Replace print with drone control command)
        print(f"t={t:.1f}s | pos=({kf_x.x:.2f}, {kf_y.x:.2f}, {kf_z.x:.2f})")

if __name__ == "__main__":
    main()
# Out:
# Terrain masking: Adjusted altitude to 40.1m
# t=0.0s | pos=(0.20, 0.35, 40.09)
# Terrain masking: Adjusted altitude to 39.9m
# t=0.1s | pos=(-0.11, 0.20, 39.95)
# Terrain masking: Adjusted altitude to 39.9m
# t=0.2s | pos=(-0.25, 0.17, 39.89)
# Terrain masking: Adjusted altitude to 40.1m
# t=0.3s | pos=(0.13, -0.04, 40.06)
# Terrain masking: Adjusted altitude to 40.0m
# t=0.4s | pos=(0.06, -0.02, 40.03)
# Terrain masking: Adjusted altitude to 40.1m
# t=0.5s | pos=(0.13, 0.10, 40.06)
# Terrain masking: Adjusted altitude to 40.1m
# t=0.6s | pos=(0.12, -0.05, 40.05)
# Terrain masking: Adjusted altitude to 40.1m
# t=0.7s | pos=(0.26, 0.12, 40.12)
# Terrain masking: Adjusted altitude to 40.0m
# t=0.8s | pos=(-0.02, 0.16, 39.99)
# Terrain masking: Adjusted altitude to 39.9m
# t=0.9s | pos=(-0.14, 0.39, 39.94)
# Terrain masking: Adjusted altitude to 40.0m
# t=1.0s | pos=(-0.04, 0.29, 39.98)
# Terrain masking: Adjusted altitude to 40.0m
# t=1.1s | pos=(0.07, 0.35, 40.03)
# Terrain masking: Adjusted altitude to 40.0m
# t=1.2s | pos=(0.06, 0.22, 40.03)
# Terrain masking: Adjusted altitude to 40.0m
# t=1.3s | pos=(-0.02, 0.23, 39.99)
# Terrain masking: Adjusted altitude to 40.0m
# t=1.4s | pos=(0.05, 0.20, 40.02)
# Terrain masking: Adjusted altitude to 40.0m
# t=1.5s | pos=(0.05, 0.30, 40.02)
# Terrain masking: Adjusted altitude to 40.1m
# t=1.6s | pos=(0.31, 0.34, 40.14)
# Terrain masking: Adjusted altitude to 40.2m
# t=1.7s | pos=(0.45, 0.30, 40.20)
# Terrain masking: Adjusted altitude to 40.1m
# t=1.8s | pos=(0.28, 0.05, 40.13)
# Terrain masking: Adjusted altitude to 40.0m
# t=1.9s | pos=(-0.08, 0.13, 39.96)
# Terrain masking: Adjusted altitude to 40.0m
# t=2.0s | pos=(0.03, -0.03, 40.01)
# Terrain masking: Adjusted altitude to 39.9m
# t=2.1s | pos=(-0.29, 0.04, 39.87)
# Terrain masking: Adjusted altitude to 40.0m
# t=2.2s | pos=(-0.00, 0.07, 40.00)
# Terrain masking: Adjusted altitude to 40.1m
# t=2.3s | pos=(0.21, 0.06, 40.10)
# Terrain masking: Adjusted altitude to 40.0m
# t=2.4s | pos=(0.07, -0.12, 40.03)
# Terrain masking: Adjusted altitude to 40.0m
# t=2.5s | pos=(-0.10, -0.13, 39.96)
# Terrain masking: Adjusted altitude to 39.9m
# t=2.6s | pos=(-0.17, -0.21, 39.93)
# Terrain masking: Adjusted altitude to 39.9m
# t=2.7s | pos=(-0.30, -0.35, 39.86)
# Terrain masking: Adjusted altitude to 39.8m
# t=2.8s | pos=(-0.40, -0.14, 39.82)
# Terrain masking: Adjusted altitude to 39.8m
# t=2.9s | pos=(-0.48, -0.09, 39.78)
# Terrain masking: Adjusted altitude to 39.9m
# t=3.0s | pos=(-0.33, -0.02, 39.85)
# Terrain masking: Adjusted altitude to 39.9m
# t=3.1s | pos=(-0.13, -0.05, 39.94)
# Terrain masking: Adjusted altitude to 40.0m
# t=3.2s | pos=(0.03, -0.11, 40.01)
# Terrain masking: Adjusted altitude to 40.0m
# t=3.3s | pos=(-0.05, -0.02, 39.98)
# Terrain masking: Adjusted altitude to 40.0m
# t=3.4s | pos=(0.05, 0.16, 40.02)
# Terrain masking: Adjusted altitude to 40.0m
# t=3.5s | pos=(-0.10, 0.27, 39.96)
# Terrain masking: Adjusted altitude to 40.0m
# t=3.6s | pos=(0.04, 0.14, 40.02)
# Terrain masking: Adjusted altitude to 40.0m
# t=3.7s | pos=(-0.02, 0.17, 39.99)
# Terrain masking: Adjusted altitude to 40.0m
# t=3.8s | pos=(-0.11, 0.26, 39.95)
# Terrain masking: Adjusted altitude to 40.0m
# t=3.9s | pos=(-0.09, 0.27, 39.96)
# Terrain masking: Adjusted altitude to 39.9m
# t=4.0s | pos=(-0.14, 0.06, 39.94)
# Terrain masking: Adjusted altitude to 40.0m
# t=4.1s | pos=(0.01, -0.10, 40.00)
# Terrain masking: Adjusted altitude to 40.0m
# t=4.2s | pos=(-0.07, -0.17, 39.97)
# Terrain masking: Adjusted altitude to 40.1m
# t=4.3s | pos=(0.12, -0.12, 40.05)
# Terrain masking: Adjusted altitude to 40.0m
# t=4.4s | pos=(0.01, -0.11, 40.00)
# Terrain masking: Adjusted altitude to 39.9m
# t=4.5s | pos=(-0.22, 0.00, 39.90)
# Terrain masking: Adjusted altitude to 39.9m
# t=4.6s | pos=(-0.11, 0.19, 39.95)
# Terrain masking: Adjusted altitude to 40.0m
# t=4.7s | pos=(-0.05, 0.11, 39.98)
# Terrain masking: Adjusted altitude to 40.0m
# t=4.8s | pos=(-0.04, 0.15, 39.98)
# Terrain masking: Adjusted altitude to 40.0m
# t=4.9s | pos=(0.03, 0.38, 40.01)
# Terrain masking: Adjusted altitude to 40.1m
# t=5.0s | pos=(0.28, 0.36, 40.13)
# Terrain masking: Adjusted altitude to 40.0m
# t=5.1s | pos=(-0.01, 0.04, 40.00)
# Terrain masking: Adjusted altitude to 39.9m
# t=5.2s | pos=(-0.15, 0.03, 39.93)
# Terrain masking: Adjusted altitude to 40.0m
# t=5.3s | pos=(-0.09, -0.04, 39.96)
# Terrain masking: Adjusted altitude to 40.1m
# t=5.4s | pos=(0.15, -0.19, 40.07)
# Terrain masking: Adjusted altitude to 40.1m
# t=5.5s | pos=(0.24, -0.30, 40.11)
# Terrain masking: Adjusted altitude to 40.1m
# t=5.6s | pos=(0.22, -0.13, 40.10)
# Terrain masking: Adjusted altitude to 40.1m
# t=5.7s | pos=(0.17, -0.21, 40.08)
# Terrain masking: Adjusted altitude to 40.2m
# t=5.8s | pos=(0.45, -0.27, 40.20)
# Terrain masking: Adjusted altitude to 40.2m
# t=5.9s | pos=(0.37, -0.21, 40.17)
# Terrain masking: Adjusted altitude to 40.1m
# t=6.0s | pos=(0.33, -0.20, 40.15)
# Terrain masking: Adjusted altitude to 40.1m
# t=6.1s | pos=(0.18, -0.12, 40.08)
# Terrain masking: Adjusted altitude to 40.0m
# t=6.2s | pos=(0.09, -0.01, 40.04)
# Terrain masking: Adjusted altitude to 40.1m
# t=6.3s | pos=(0.19, -0.15, 40.08)
# Terrain masking: Adjusted altitude to 40.0m
# t=6.4s | pos=(0.08, -0.24, 40.04)
# Terrain masking: Adjusted altitude to 40.1m
# t=6.5s | pos=(0.15, -0.31, 40.07)
# Terrain masking: Adjusted altitude to 40.1m
# t=6.6s | pos=(0.30, -0.29, 40.14)
# Terrain masking: Adjusted altitude to 40.0m
# t=6.7s | pos=(-0.06, 0.07, 39.97)
# Terrain masking: Adjusted altitude to 40.0m
# t=6.8s | pos=(-0.07, 0.08, 39.97)
# Terrain masking: Adjusted altitude to 39.9m
# t=6.9s | pos=(-0.13, 0.12, 39.94)
# Terrain masking: Adjusted altitude to 39.9m
# t=7.0s | pos=(-0.14, 0.10, 39.94)
# Terrain masking: Adjusted altitude to 40.0m
# t=7.1s | pos=(-0.04, 0.06, 39.98)
# Terrain masking: Adjusted altitude to 40.0m
# t=7.2s | pos=(0.09, 0.33, 40.04)
# Terrain masking: Adjusted altitude to 40.1m
# t=7.3s | pos=(0.20, 0.30, 40.09)
# Terrain masking: Adjusted altitude to 40.0m
# t=7.4s | pos=(0.04, 0.15, 40.02)
# Terrain masking: Adjusted altitude to 40.0m
# t=7.5s | pos=(-0.03, -0.09, 39.99)
# Terrain masking: Adjusted altitude to 40.0m
# t=7.6s | pos=(-0.01, -0.04, 39.99)
# Terrain masking: Adjusted altitude to 40.0m
# t=7.7s | pos=(0.07, -0.21, 40.03)
# Terrain masking: Adjusted altitude to 40.1m
# t=7.8s | pos=(0.27, -0.00, 40.12)
# Terrain masking: Adjusted altitude to 40.1m
# t=7.9s | pos=(0.21, -0.05, 40.10)
# Terrain masking: Adjusted altitude to 40.0m
# t=8.0s | pos=(0.04, -0.17, 40.02)
# Terrain masking: Adjusted altitude to 39.9m
# t=8.1s | pos=(-0.21, -0.13, 39.91)
# Terrain masking: Adjusted altitude to 39.8m
# t=8.2s | pos=(-0.38, -0.09, 39.83)
# Terrain masking: Adjusted altitude to 39.8m
# t=8.3s | pos=(-0.34, -0.08, 39.85)
# Terrain masking: Adjusted altitude to 39.9m
# t=8.4s | pos=(-0.26, -0.09, 39.88)
# Terrain masking: Adjusted altitude to 39.9m
# t=8.5s | pos=(-0.32, -0.24, 39.86)
# Terrain masking: Adjusted altitude to 39.9m
# t=8.6s | pos=(-0.20, -0.32, 39.91)
# Terrain masking: Adjusted altitude to 39.8m
# t=8.7s | pos=(-0.38, -0.22, 39.83)
# Terrain masking: Adjusted altitude to 39.9m
# t=8.8s | pos=(-0.19, -0.18, 39.92)
# Terrain masking: Adjusted altitude to 40.0m
# t=8.9s | pos=(0.02, -0.17, 40.01)
# Terrain masking: Adjusted altitude to 40.0m
# t=9.0s | pos=(-0.04, 0.18, 39.98)
# Terrain masking: Adjusted altitude to 40.0m
# t=9.1s | pos=(-0.03, 0.15, 39.98)
# Terrain masking: Adjusted altitude to 40.0m
# t=9.2s | pos=(-0.02, 0.09, 39.99)
# Terrain masking: Adjusted altitude to 39.9m
# t=9.3s | pos=(-0.16, -0.01, 39.93)
# Terrain masking: Adjusted altitude to 39.9m
# t=9.4s | pos=(-0.19, 0.12, 39.91)
# Terrain masking: Adjusted altitude to 39.8m
# t=9.5s | pos=(-0.34, 0.13, 39.85)
# Terrain masking: Adjusted altitude to 39.9m
# t=9.6s | pos=(-0.25, 0.30, 39.89)
# Terrain masking: Adjusted altitude to 39.8m
# t=9.7s | pos=(-0.46, 0.05, 39.79)
# Terrain masking: Adjusted altitude to 39.8m
# t=9.8s | pos=(-0.44, 0.05, 39.80)
# Terrain masking: Adjusted altitude to 39.8m
# t=9.9s | pos=(-0.47, 0.08, 39.79)
# Terrain masking: Adjusted altitude to 39.8m
# t=10.0s | pos=(-0.36, -0.06, 39.84)
# Terrain masking: Adjusted altitude to 39.8m
# t=10.1s | pos=(-0.41, -0.08, 39.82)
# Terrain masking: Adjusted altitude to 39.9m
# t=10.2s | pos=(-0.28, -0.22, 39.87)
# Terrain masking: Adjusted altitude to 39.9m
# t=10.3s | pos=(-0.23, -0.22, 39.90)
# Terrain masking: Adjusted altitude to 39.9m
# t=10.4s | pos=(-0.30, 0.00, 39.87)
# Terrain masking: Adjusted altitude to 39.9m
# t=10.5s | pos=(-0.16, -0.02, 39.93)
# Terrain masking: Adjusted altitude to 40.0m
# t=10.6s | pos=(-0.09, -0.17, 39.96)
# Terrain masking: Adjusted altitude to 40.0m
# t=10.7s | pos=(0.01, 0.06, 40.01)
# Terrain masking: Adjusted altitude to 40.1m
# t=10.8s | pos=(0.18, 0.19, 40.08)
# Terrain masking: Adjusted altitude to 40.1m
# t=10.9s | pos=(0.12, 0.02, 40.05)
# Terrain masking: Adjusted altitude to 40.0m
# t=11.0s | pos=(0.06, -0.10, 40.03)
# Terrain masking: Adjusted altitude to 40.1m
# t=11.1s | pos=(0.27, -0.19, 40.12)
# Terrain masking: Adjusted altitude to 40.0m
# t=11.2s | pos=(0.10, -0.09, 40.04)
# Terrain masking: Adjusted altitude to 40.0m
# t=11.3s | pos=(-0.06, -0.10, 39.97)
# Terrain masking: Adjusted altitude to 39.9m
# t=11.4s | pos=(-0.27, -0.12, 39.88)
# Terrain masking: Adjusted altitude to 39.9m
# t=11.5s | pos=(-0.24, -0.11, 39.89)
# Terrain masking: Adjusted altitude to 39.9m
# t=11.6s | pos=(-0.19, -0.32, 39.91)
# Terrain masking: Adjusted altitude to 39.9m
# t=11.7s | pos=(-0.19, -0.64, 39.91)
# Terrain masking: Adjusted altitude to 40.0m
# t=11.8s | pos=(-0.08, -0.51, 39.97)
# Terrain masking: Adjusted altitude to 40.0m
# t=11.9s | pos=(-0.07, -0.22, 39.97)
# Terrain masking: Adjusted altitude to 40.1m
# t=12.0s | pos=(0.11, -0.30, 40.05)
# Terrain masking: Adjusted altitude to 40.0m
# t=12.1s | pos=(0.03, -0.43, 40.02)
# Terrain masking: Adjusted altitude to 40.0m
# t=12.2s | pos=(0.06, -0.56, 40.03)
# Terrain masking: Adjusted altitude to 40.0m
# t=12.3s | pos=(0.05, -0.23, 40.02)
# Terrain masking: Adjusted altitude to 40.1m
# t=12.4s | pos=(0.15, -0.25, 40.07)
# Terrain masking: Adjusted altitude to 40.0m
# t=12.5s | pos=(-0.07, -0.11, 39.97)
# Terrain masking: Adjusted altitude to 39.9m
# t=12.6s | pos=(-0.19, 0.21, 39.91)
# Terrain masking: Adjusted altitude to 39.9m
# t=12.7s | pos=(-0.21, 0.27, 39.91)
# Terrain masking: Adjusted altitude to 39.8m
# t=12.8s | pos=(-0.37, 0.39, 39.83)
# Terrain masking: Adjusted altitude to 39.9m
# t=12.9s | pos=(-0.33, 0.35, 39.85)
# Terrain masking: Adjusted altitude to 39.8m
# t=13.0s | pos=(-0.46, 0.16, 39.79)
# Terrain masking: Adjusted altitude to 39.7m
# t=13.1s | pos=(-0.59, 0.26, 39.73)
# Terrain masking: Adjusted altitude to 39.7m
# t=13.2s | pos=(-0.75, 0.14, 39.66)
# Terrain masking: Adjusted altitude to 39.8m
# t=13.3s | pos=(-0.54, 0.12, 39.75)
# Terrain masking: Adjusted altitude to 39.8m
# t=13.4s | pos=(-0.44, 0.04, 39.80)
# Terrain masking: Adjusted altitude to 39.8m
# t=13.5s | pos=(-0.40, 0.08, 39.82)
# Terrain masking: Adjusted altitude to 39.9m
# t=13.6s | pos=(-0.30, 0.21, 39.87)
# Terrain masking: Adjusted altitude to 39.9m
# t=13.7s | pos=(-0.28, 0.14, 39.88)
# Terrain masking: Adjusted altitude to 39.8m
# t=13.8s | pos=(-0.43, 0.14, 39.80)
# Terrain masking: Adjusted altitude to 39.8m
# t=13.9s | pos=(-0.49, 0.15, 39.78)
# Terrain masking: Adjusted altitude to 39.9m
# t=14.0s | pos=(-0.30, 0.19, 39.86)
# Terrain masking: Adjusted altitude to 39.9m
# t=14.1s | pos=(-0.17, 0.27, 39.93)
# Terrain masking: Adjusted altitude to 39.9m
# t=14.2s | pos=(-0.12, 0.07, 39.94)
# Terrain masking: Adjusted altitude to 40.0m
# t=14.3s | pos=(0.09, 0.02, 40.04)
# Terrain masking: Adjusted altitude to 40.1m
# t=14.4s | pos=(0.15, 0.35, 40.07)
# Terrain masking: Adjusted altitude to 40.1m
# t=14.5s | pos=(0.26, 0.17, 40.12)
# Terrain masking: Adjusted altitude to 40.1m
# t=14.6s | pos=(0.29, 0.08, 40.13)
# Terrain masking: Adjusted altitude to 40.2m
# t=14.7s | pos=(0.42, 0.23, 40.19)
# Terrain masking: Adjusted altitude to 40.2m
# t=14.8s | pos=(0.45, 0.04, 40.20)
# Terrain masking: Adjusted altitude to 40.1m
# t=14.9s | pos=(0.33, -0.13, 40.15)
# Terrain masking: Adjusted altitude to 40.2m
# t=15.0s | pos=(0.45, 0.11, 40.20)
# Terrain masking: Adjusted altitude to 40.2m
# t=15.1s | pos=(0.43, 0.12, 40.19)
# Terrain masking: Adjusted altitude to 40.2m
# t=15.2s | pos=(0.35, 0.29, 40.16)
# Terrain masking: Adjusted altitude to 40.1m
# t=15.3s | pos=(0.11, 0.19, 40.05)
# Terrain masking: Adjusted altitude to 40.2m
# t=15.4s | pos=(0.34, -0.14, 40.15)
# Terrain masking: Adjusted altitude to 40.1m
# t=15.5s | pos=(0.12, -0.20, 40.06)
# Terrain masking: Adjusted altitude to 40.0m
# t=15.6s | pos=(0.08, -0.13, 40.04)
# Terrain masking: Adjusted altitude to 40.0m
# t=15.7s | pos=(0.00, -0.09, 40.00)
# Terrain masking: Adjusted altitude to 40.0m
# t=15.8s | pos=(0.06, -0.11, 40.02)
# Terrain masking: Adjusted altitude to 40.0m
# t=15.9s | pos=(0.08, 0.02, 40.04)
# Terrain masking: Adjusted altitude to 39.9m
# t=16.0s | pos=(-0.16, -0.22, 39.93)
# Terrain masking: Adjusted altitude to 39.9m
# t=16.1s | pos=(-0.32, -0.17, 39.86)
# Terrain masking: Adjusted altitude to 39.8m
# t=16.2s | pos=(-0.37, -0.24, 39.83)
# Terrain masking: Adjusted altitude to 39.9m
# t=16.3s | pos=(-0.11, -0.25, 39.95)
# Terrain masking: Adjusted altitude to 39.9m
# t=16.4s | pos=(-0.21, -0.04, 39.91)
# Terrain masking: Adjusted altitude to 39.9m
# t=16.5s | pos=(-0.29, 0.02, 39.87)
# Terrain masking: Adjusted altitude to 40.0m
# t=16.6s | pos=(-0.01, -0.08, 40.00)
# Terrain masking: Adjusted altitude to 40.0m
# t=16.7s | pos=(-0.07, -0.13, 39.97)
# Terrain masking: Adjusted altitude to 40.0m
# t=16.8s | pos=(-0.07, -0.08, 39.97)
# Terrain masking: Adjusted altitude to 39.9m
# t=16.9s | pos=(-0.14, -0.03, 39.94)
# Terrain masking: Adjusted altitude to 40.0m
# t=17.0s | pos=(-0.08, 0.13, 39.96)
# Terrain masking: Adjusted altitude to 40.0m
# t=17.1s | pos=(-0.01, 0.19, 39.99)
# Terrain masking: Adjusted altitude to 40.1m
# t=17.2s | pos=(0.19, 0.29, 40.09)
# Terrain masking: Adjusted altitude to 40.2m
# t=17.3s | pos=(0.46, 0.48, 40.20)
# Terrain masking: Adjusted altitude to 40.2m
# t=17.4s | pos=(0.36, 0.51, 40.16)
# Terrain masking: Adjusted altitude to 40.1m
# t=17.5s | pos=(0.13, 0.38, 40.06)
# Terrain masking: Adjusted altitude to 40.0m
# t=17.6s | pos=(0.02, 0.06, 40.01)
# Terrain masking: Adjusted altitude to 40.0m
# t=17.7s | pos=(0.00, 0.05, 40.00)
# Terrain masking: Adjusted altitude to 40.1m
# t=17.8s | pos=(0.18, 0.07, 40.08)
# Terrain masking: Adjusted altitude to 40.1m
# t=17.9s | pos=(0.25, 0.16, 40.11)
# Terrain masking: Adjusted altitude to 40.1m
# t=18.0s | pos=(0.21, 0.12, 40.10)
# Terrain masking: Adjusted altitude to 40.1m
# t=18.1s | pos=(0.12, 0.18, 40.05)
# Terrain masking: Adjusted altitude to 40.0m
# t=18.2s | pos=(0.06, 0.00, 40.03)
# Terrain masking: Adjusted altitude to 40.0m
# t=18.3s | pos=(0.06, 0.07, 40.03)
# Terrain masking: Adjusted altitude to 40.0m
# t=18.4s | pos=(0.07, 0.06, 40.03)
# Terrain masking: Adjusted altitude to 40.0m
# t=18.5s | pos=(0.05, 0.18, 40.02)
# Terrain masking: Adjusted altitude to 40.1m
# t=18.6s | pos=(0.29, -0.02, 40.13)
# Terrain masking: Adjusted altitude to 40.1m
# t=18.7s | pos=(0.18, -0.04, 40.08)
# Terrain masking: Adjusted altitude to 40.1m
# t=18.8s | pos=(0.16, -0.07, 40.07)
# Terrain masking: Adjusted altitude to 40.1m
# t=18.9s | pos=(0.11, 0.02, 40.05)
# Terrain masking: Adjusted altitude to 39.9m
# t=19.0s | pos=(-0.14, 0.24, 39.94)
# Terrain masking: Adjusted altitude to 40.0m
# t=19.1s | pos=(-0.05, -0.07, 39.98)
# Terrain masking: Adjusted altitude to 40.0m
# t=19.2s | pos=(-0.03, -0.02, 39.98)
# Terrain masking: Adjusted altitude to 40.0m
# t=19.3s | pos=(-0.09, 0.03, 39.96)
# Terrain masking: Adjusted altitude to 40.0m
# t=19.4s | pos=(-0.08, -0.08, 39.96)
# Terrain masking: Adjusted altitude to 40.0m
# t=19.5s | pos=(0.01, -0.15, 40.00)
# Terrain masking: Adjusted altitude to 39.9m
# t=19.6s | pos=(-0.14, -0.11, 39.94)
# Terrain masking: Adjusted altitude to 40.0m
# t=19.7s | pos=(0.00, 0.06, 40.00)
# Terrain masking: Adjusted altitude to 40.1m
# t=19.8s | pos=(0.12, 0.31, 40.05)
# Terrain masking: Adjusted altitude to 40.0m
# t=19.9s | pos=(-0.07, 0.24, 39.97)
# Terrain masking: Adjusted altitude to 40.0m
# t=20.0s | pos=(-0.06, 0.36, 39.97)
# Terrain masking: Adjusted altitude to 39.9m
# t=20.1s | pos=(-0.32, 0.33, 39.86)
# Terrain masking: Adjusted altitude to 39.8m
# t=20.2s | pos=(-0.35, 0.30, 39.84)
# Terrain masking: Adjusted altitude to 39.9m
# t=20.3s | pos=(-0.27, 0.31, 39.88)
# Terrain masking: Adjusted altitude to 39.9m
# t=20.4s | pos=(-0.19, 0.36, 39.92)
# Terrain masking: Adjusted altitude to 39.9m
# t=20.5s | pos=(-0.26, 0.10, 39.88)
# Terrain masking: Adjusted altitude to 39.9m
# t=20.6s | pos=(-0.23, 0.14, 39.90)
# Terrain masking: Adjusted altitude to 40.0m
# t=20.7s | pos=(-0.07, 0.13, 39.97)
# Terrain masking: Adjusted altitude to 40.0m
# t=20.8s | pos=(0.09, 0.23, 40.04)
# Terrain masking: Adjusted altitude to 40.0m
# t=20.9s | pos=(-0.09, 0.16, 39.96)
# Terrain masking: Adjusted altitude to 39.9m
# t=21.0s | pos=(-0.18, 0.18, 39.92)
# Terrain masking: Adjusted altitude to 39.9m
# t=21.1s | pos=(-0.20, 0.15, 39.91)
# Terrain masking: Adjusted altitude to 40.0m
# t=21.2s | pos=(-0.10, 0.32, 39.95)
# Terrain masking: Adjusted altitude to 40.1m
# t=21.3s | pos=(0.12, 0.14, 40.05)
# Terrain masking: Adjusted altitude to 40.1m
# t=21.4s | pos=(0.15, 0.03, 40.07)
# Terrain masking: Adjusted altitude to 40.0m
# t=21.5s | pos=(-0.02, 0.09, 39.99)
# Terrain masking: Adjusted altitude to 39.9m
# t=21.6s | pos=(-0.14, -0.17, 39.94)
# Terrain masking: Adjusted altitude to 39.9m
# t=21.7s | pos=(-0.15, -0.24, 39.93)
# Terrain masking: Adjusted altitude to 40.0m
# t=21.8s | pos=(-0.02, -0.33, 39.99)
# Terrain masking: Adjusted altitude to 40.0m
# t=21.9s | pos=(-0.06, -0.40, 39.97)
# Terrain masking: Adjusted altitude to 40.0m
# t=22.0s | pos=(-0.10, -0.37, 39.95)
# Terrain masking: Adjusted altitude to 40.0m
# t=22.1s | pos=(-0.01, -0.46, 40.00)
# Terrain masking: Adjusted altitude to 39.9m
# t=22.2s | pos=(-0.29, -0.38, 39.87)
# Terrain masking: Adjusted altitude to 40.0m
# t=22.3s | pos=(-0.07, -0.03, 39.97)
# Terrain masking: Adjusted altitude to 40.0m
# t=22.4s | pos=(-0.05, 0.02, 39.98)
# Terrain masking: Adjusted altitude to 40.1m
# t=22.5s | pos=(0.16, 0.15, 40.07)
# Terrain masking: Adjusted altitude to 40.1m
# t=22.6s | pos=(0.13, 0.05, 40.06)
# Terrain masking: Adjusted altitude to 40.0m
# t=22.7s | pos=(0.09, 0.14, 40.04)
# Terrain masking: Adjusted altitude to 40.0m
# t=22.8s | pos=(-0.10, 0.20, 39.95)
# Terrain masking: Adjusted altitude to 40.0m
# t=22.9s | pos=(-0.02, 0.29, 39.99)
# Terrain masking: Adjusted altitude to 40.0m
# t=23.0s | pos=(-0.08, 0.05, 39.96)
# Terrain masking: Adjusted altitude to 39.9m
# t=23.1s | pos=(-0.20, 0.13, 39.91)
# Terrain masking: Adjusted altitude to 39.9m
# t=23.2s | pos=(-0.19, 0.25, 39.91)
# Terrain masking: Adjusted altitude to 40.0m
# t=23.3s | pos=(0.05, 0.43, 40.02)
# Terrain masking: Adjusted altitude to 40.0m
# t=23.4s | pos=(0.02, 0.50, 40.01)
# Terrain masking: Adjusted altitude to 40.1m
# t=23.5s | pos=(0.26, 0.30, 40.12)
# Terrain masking: Adjusted altitude to 40.2m
# t=23.6s | pos=(0.50, 0.25, 40.22)
# Terrain masking: Adjusted altitude to 40.2m
# t=23.7s | pos=(0.43, 0.28, 40.19)
# Terrain masking: Adjusted altitude to 40.1m
# t=23.8s | pos=(0.13, 0.19, 40.06)
# Terrain masking: Adjusted altitude to 40.0m
# t=23.9s | pos=(0.10, 0.02, 40.05)
# Terrain masking: Adjusted altitude to 40.0m
# t=24.0s | pos=(-0.05, 0.33, 39.98)
# Terrain masking: Adjusted altitude to 39.9m
# t=24.1s | pos=(-0.17, 0.33, 39.92)
# Terrain masking: Adjusted altitude to 40.0m
# t=24.2s | pos=(-0.08, 0.12, 39.96)
# Terrain masking: Adjusted altitude to 40.0m
# t=24.3s | pos=(-0.03, -0.04, 39.99)
# Terrain masking: Adjusted altitude to 39.9m
# t=24.4s | pos=(-0.33, 0.05, 39.85)
# Terrain masking: Adjusted altitude to 39.9m
# t=24.5s | pos=(-0.32, 0.24, 39.86)
# Terrain masking: Adjusted altitude to 39.9m
# t=24.6s | pos=(-0.11, 0.21, 39.95)
# Terrain masking: Adjusted altitude to 39.9m
# t=24.7s | pos=(-0.17, 0.22, 39.92)
# Terrain masking: Adjusted altitude to 39.9m
# t=24.8s | pos=(-0.19, 0.19, 39.92)
# Terrain masking: Adjusted altitude to 40.0m
# t=24.9s | pos=(0.09, 0.09, 40.04)
# Terrain masking: Adjusted altitude to 40.1m
# t=25.0s | pos=(0.19, 0.12, 40.08)
# Terrain masking: Adjusted altitude to 40.1m
# t=25.1s | pos=(0.30, 0.19, 40.14)
# Terrain masking: Adjusted altitude to 40.1m
# t=25.2s | pos=(0.21, 0.02, 40.10)
# Terrain masking: Adjusted altitude to 40.0m
# t=25.3s | pos=(0.07, 0.03, 40.03)
# Terrain masking: Adjusted altitude to 40.1m
# t=25.4s | pos=(0.16, 0.01, 40.07)
# Terrain masking: Adjusted altitude to 40.0m
# t=25.5s | pos=(-0.02, 0.03, 39.99)
# Terrain masking: Adjusted altitude to 39.9m
# t=25.6s | pos=(-0.23, -0.03, 39.89)
# Terrain masking: Adjusted altitude to 39.9m
# t=25.7s | pos=(-0.18, 0.02, 39.92)
# Terrain masking: Adjusted altitude to 39.8m
# t=25.8s | pos=(-0.41, -0.09, 39.81)
# Terrain masking: Adjusted altitude to 39.9m
# t=25.9s | pos=(-0.24, -0.08, 39.89)
# Terrain masking: Adjusted altitude to 39.9m
# t=26.0s | pos=(-0.23, -0.10, 39.90)
# Terrain masking: Adjusted altitude to 39.9m
# t=26.1s | pos=(-0.18, -0.31, 39.92)
# Terrain masking: Adjusted altitude to 39.9m
# t=26.2s | pos=(-0.32, -0.27, 39.86)
# Terrain masking: Adjusted altitude to 39.9m
# t=26.3s | pos=(-0.20, -0.21, 39.91)
# Terrain masking: Adjusted altitude to 40.0m
# t=26.4s | pos=(0.09, -0.27, 40.04)
# Terrain masking: Adjusted altitude to 40.1m
# t=26.5s | pos=(0.14, -0.10, 40.06)
# Terrain masking: Adjusted altitude to 40.1m
# t=26.6s | pos=(0.14, 0.08, 40.06)
# Terrain masking: Adjusted altitude to 40.1m
# t=26.7s | pos=(0.18, -0.14, 40.08)
# Terrain masking: Adjusted altitude to 40.0m
# t=26.8s | pos=(0.04, -0.22, 40.02)
# Terrain masking: Adjusted altitude to 40.0m
# t=26.9s | pos=(-0.01, -0.12, 40.00)
# Terrain masking: Adjusted altitude to 40.0m
# t=27.0s | pos=(-0.01, 0.14, 39.99)
# Terrain masking: Adjusted altitude to 40.1m
# t=27.1s | pos=(0.23, 0.12, 40.10)
# Terrain masking: Adjusted altitude to 40.1m
# t=27.2s | pos=(0.27, 0.10, 40.12)
# Terrain masking: Adjusted altitude to 40.1m
# t=27.3s | pos=(0.26, 0.27, 40.12)
# Terrain masking: Adjusted altitude to 40.2m
# t=27.4s | pos=(0.37, 0.63, 40.17)
# Terrain masking: Adjusted altitude to 40.2m
# t=27.5s | pos=(0.42, 0.42, 40.19)
# Terrain masking: Adjusted altitude to 40.1m
# t=27.6s | pos=(0.17, 0.34, 40.08)
# Terrain masking: Adjusted altitude to 40.0m
# t=27.7s | pos=(0.08, 0.43, 40.03)
# Terrain masking: Adjusted altitude to 40.1m
# t=27.8s | pos=(0.13, 0.24, 40.06)
# Terrain masking: Adjusted altitude to 40.1m
# t=27.9s | pos=(0.25, 0.35, 40.11)
# Terrain masking: Adjusted altitude to 40.1m
# t=28.0s | pos=(0.19, 0.50, 40.09)
# Terrain masking: Adjusted altitude to 40.1m
# t=28.1s | pos=(0.21, 0.44, 40.09)
# Terrain masking: Adjusted altitude to 40.1m
# t=28.2s | pos=(0.19, 0.30, 40.09)
# Terrain masking: Adjusted altitude to 40.1m
# t=28.3s | pos=(0.19, 0.23, 40.09)
# Terrain masking: Adjusted altitude to 40.1m
# t=28.4s | pos=(0.21, 0.20, 40.09)
# Terrain masking: Adjusted altitude to 40.0m
# t=28.5s | pos=(0.03, 0.26, 40.02)
# Terrain masking: Adjusted altitude to 40.1m
# t=28.6s | pos=(0.17, 0.51, 40.08)
# Terrain masking: Adjusted altitude to 40.1m
# t=28.7s | pos=(0.25, 0.62, 40.11)
# Terrain masking: Adjusted altitude to 40.0m
# t=28.8s | pos=(-0.02, 0.56, 39.99)
# Terrain masking: Adjusted altitude to 40.1m
# t=28.9s | pos=(0.17, 0.32, 40.07)
# Terrain masking: Adjusted altitude to 40.1m
# t=29.0s | pos=(0.23, 0.43, 40.11)
# Terrain masking: Adjusted altitude to 40.1m
# t=29.1s | pos=(0.21, 0.18, 40.10)
# Terrain masking: Adjusted altitude to 40.1m
# t=29.2s | pos=(0.21, 0.45, 40.09)
# Terrain masking: Adjusted altitude to 40.1m
# t=29.3s | pos=(0.14, 0.28, 40.06)
# Terrain masking: Adjusted altitude to 40.1m
# t=29.4s | pos=(0.25, 0.11, 40.11)
# Terrain masking: Adjusted altitude to 40.0m
# t=29.5s | pos=(0.08, 0.13, 40.04)
# Terrain masking: Adjusted altitude to 40.0m
# t=29.6s | pos=(0.01, 0.21, 40.00)
# Terrain masking: Adjusted altitude to 40.1m
# t=29.7s | pos=(0.12, 0.19, 40.05)
# Terrain masking: Adjusted altitude to 40.1m
# t=29.8s | pos=(0.23, 0.28, 40.11)
# Terrain masking: Adjusted altitude to 40.1m
# t=29.9s | pos=(0.20, 0.17, 40.09)

# %% [markdown]
# How This Works
# 1. Kalman Filters for Sensor Fusion
# Each axis (x, y, z) has its own Kalman filter, fusing acceleration and position measurements to estimate position and velocity, robust to noise and drift.
# 2. Obstacle Avoidance
# Simulated LIDAR returns distances; if any reading is below the min_dist, an obstacle is detected and a turn direction is chosen.
# 3. Terrain Masking
# The drone’s altitude is always kept above the local terrain plus a buffer, using a digital elevation model (DEM).
# 4. Real Sensor API Integration
# Replace the RealSensorAPI stubs with actual calls to hardware (quantum IMU, magnetometer, LIDAR, etc.).
# To Integrate Real Sensors:
#
# Use the SDK or API provided by the sensor manufacturer for quantum IMU, LIDAR, etc.
# Replace the methods in RealSensorAPI with actual sensor reads (e.g., via USB, UART, CAN, or ROS topics).
